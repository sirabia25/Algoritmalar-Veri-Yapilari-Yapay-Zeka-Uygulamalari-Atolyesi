# %% [markdown]
# 18.04.2026
# istanbul
# >
# #VeriyiİsleGeleceği Kodla
# <>
# Algoritmalar, Veri Yapıları & Yapay
# Zeka Uygulamaları Atölyesi

# %%
print("hello world")
# Out:
# hello world

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan bi print
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/GoogleColab')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/GoogleColab
